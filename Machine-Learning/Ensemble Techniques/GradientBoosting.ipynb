# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
X,y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
gradient_clf = GradientBoostingClassifier()

# %%
gradient_clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred = gradient_clf.predict(X_test)

# %%
print("Current model performance:")
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Current model performance:
# Accuracy: 0.86
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86       158
#            1       0.84      0.87      0.86       142
#
#     accuracy                           0.86       300
#    macro avg       0.86      0.86      0.86       300
# weighted avg       0.86      0.86      0.86       300
#
# Confusion Matrix:
# [[134  24]
#  [ 18 124]]

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.05, 0.2]
}

# %%
grid_search = GridSearchCV(estimator=gradient_clf, param_grid=param_grid, cv=5, verbose=3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=0.857 total time=   0.9s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=0.807 total time=   0.9s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=0.864 total time=   0.8s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=0.879 total time=   0.8s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=0.871 total time=   0.9s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=0.864 total time=   1.6s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=0.807 total time=   2.0s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=0.871 total time=   1.6s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=0.879 total time=   1.3s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=0.864 total time=   1.2s
# [CV 1/5] END learning_rate=0.01, n_estimators=300;, score=0.864 total time=   1.4s
# [CV 2/5] END learning_rate=0.01, n_estimators=300;, score=0.807 total time=   1.4s
# [CV 3/5] END learning_rate=0.01, n_estimators=300;, score=0.871 total time=   1.4s
# [CV 4/5] END learning_rate=0.01, n_estimators=300;, score=0.871 total time=   1.4s
# [CV 5/5] END learning_rate=0.01, n_estimators=300;, score=0.864 total time=   1.4s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=0.857 total time=   0.5s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=0.800 total time=   0.5s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=0.864 total time=   0.5s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=0.893 total time=   0.5s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=0.850 total time=   0.5s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=0.843 total time=   1.4s
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=0.786 total time=   1.0s
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=0.871 total time=   1.0s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=0.886 total time=   0.9s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=0.857 total time=   1.0s
# [CV 1/5] END learning_rate=0.1, n_estimators=300;, score=0.857 total time=   1.4s
# [CV 2/5] END learning_rate=0.1, n_estimators=300;, score=0.771 total time=   1.4s
# [CV 3/5] END learning_rate=0.1, n_estimators=300;, score=0.871 total time=   1.5s
# [CV 4/5] END learning_rate=0.1, n_estimators=300;, score=0.864 total time=   1.5s
# [CV 5/5] END learning_rate=0.1, n_estimators=300;, score=0.864 total time=   1.8s
# [CV 1/5] END learning_rate=0.05, n_estimators=100;, score=0.871 total time=   0.5s
# [CV 2/5] END learning_rate=0.05, n_estimators=100;, score=0.807 total time=   0.5s
# [CV 3/5] END learning_rate=0.05, n_estimators=100;, score=0.871 total time=   0.5s
# [CV 4/5] END learning_rate=0.05, n_estimators=100;, score=0.879 total time=   0.5s
# [CV 5/5] END learning_rate=0.05, n_estimators=100;, score=0.864 total time=   0.5s
# [CV 1/5] END learning_rate=0.05, n_estimators=200;, score=0.843 total time=   1.0s
# [CV 2/5] END learning_rate=0.05, n_estimators=200;, score=0.793 total time=   1.0s
# [CV 3/5] END learning_rate=0.05, n_estimators=200;, score=0.864 total time=   1.0s
# [CV 4/5] END learning_rate=0.05, n_estimators=200;, score=0.893 total time=   1.0s
# [CV 5/5] END learning_rate=0.05, n_estimators=200;, score=0.850 total time=   1.0s
# [CV 1/5] END learning_rate=0.05, n_estimators=300;, score=0.843 total time=   1.4s
# [CV 2/5] END learning_rate=0.05, n_estimators=300;, score=0.786 total time=   1.5s
# [CV 3/5] END learning_rate=0.05, n_estimators=300;, score=0.871 total time=   1.8s
# [CV 4/5] END learning_rate=0.05, n_estimators=300;, score=0.879 total time=   1.4s
# [CV 5/5] END learning_rate=0.05, n_estimators=300;, score=0.843 total time=   1.4s
# [CV 1/5] END learning_rate=0.2, n_estimators=100;, score=0.836 total time=   0.5s
# [CV 2/5] END learning_rate=0.2, n_estimators=100;, score=0.779 total time=   0.5s
# [CV 3/5] END learning_rate=0.2, n_estimators=100;, score=0.871 total time=   0.5s
# [CV 4/5] END learning_rate=0.2, n_estimators=100;, score=0.843 total time=   0.5s
# [CV 5/5] END learning_rate=0.2, n_estimators=100;, score=0.850 total time=   0.5s
# [CV 1/5] END learning_rate=0.2, n_estimators=200;, score=0.821 total time=   0.9s
# [CV 2/5] END learning_rate=0.2, n_estimators=200;, score=0.771 total time=   0.9s
# [CV 3/5] END learning_rate=0.2, n_estimators=200;, score=0.879 total time=   0.9s
# [CV 4/5] END learning_rate=0.2, n_estimators=200;, score=0.871 total time=   1.0s
# [CV 5/5] END learning_rate=0.2, n_estimators=200;, score=0.857 total time=   1.2s
# [CV 1/5] END learning_rate=0.2, n_estimators=300;, score=0.836 total time=   1.6s
# [CV 2/5] END learning_rate=0.2, n_estimators=300;, score=0.786 total time=   1.9s
# [CV 3/5] END learning_rate=0.2, n_estimators=300;, score=0.879 total time=   1.6s
# [CV 4/5] END learning_rate=0.2, n_estimators=300;, score=0.871 total time=   1.4s
# [CV 5/5] END learning_rate=0.2, n_estimators=300;, score=0.843 total time=   1.4s
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.05, 0.2],
#                          'n_estimators': [100, 200, 300]},
#              verbose=3)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.05, 'n_estimators': 100}

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# %%
print("Tuned model performance:")
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Tuned model performance:
# Accuracy: 0.8666666666666667
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       158
#            1       0.85      0.87      0.86       142
#
#     accuracy                           0.87       300
#    macro avg       0.87      0.87      0.87       300
# weighted avg       0.87      0.87      0.87       300
#
# Confusion Matrix:
# [[136  22]
#  [ 18 124]]

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
X,y = make_regression(n_samples=1000, n_features=20, noise=10, random_state=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
gradient_reg = GradientBoostingRegressor()

# %%
gradient_reg.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = gradient_reg.predict(X_test)

# %%
print("Current model performance:")
print(f"R2 score: {r2_score(y_test, y_pred)}")
print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
# Out:
# Current model performance:
# R2 score: 0.9076730065197605
# Mean Absolute Error: 35.21408540414373
# Mean Squared Error: 2046.0831296507956

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.05, 0.2]
}

# %%
grb = GradientBoostingRegressor()

# %%
grid_search = GridSearchCV(estimator=grb, param_grid=param_grid, cv=5, verbose=3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=0.457 total time=   0.4s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=0.454 total time=   0.4s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=0.427 total time=   0.4s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=0.481 total time=   0.6s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=0.469 total time=   0.6s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=0.629 total time=   0.9s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=0.626 total time=   0.9s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=0.586 total time=   0.9s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=0.655 total time=   0.9s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=0.642 total time=   0.9s
# [CV 1/5] END learning_rate=0.01, n_estimators=300;, score=0.725 total time=   1.3s
# [CV 2/5] END learning_rate=0.01, n_estimators=300;, score=0.718 total time=   1.3s
# [CV 3/5] END learning_rate=0.01, n_estimators=300;, score=0.686 total time=   1.3s
# [CV 4/5] END learning_rate=0.01, n_estimators=300;, score=0.744 total time=   1.3s
# [CV 5/5] END learning_rate=0.01, n_estimators=300;, score=0.729 total time=   1.6s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=0.895 total time=   0.5s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=0.878 total time=   0.4s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=0.869 total time=   0.4s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=0.898 total time=   0.4s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=0.890 total time=   0.4s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=0.920 total time=   0.9s
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=0.901 total time=   0.9s
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=0.894 total time=   0.9s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=0.918 total time=   0.9s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=0.914 total time=   0.9s
# [CV 1/5] END learning_rate=0.1, n_estimators=300;, score=0.924 total time=   1.3s
# [CV 2/5] END learning_rate=0.1, n_estimators=300;, score=0.905 total time=   1.3s
# [CV 3/5] END learning_rate=0.1, n_estimators=300;, score=0.893 total time=   1.5s
# [CV 4/5] END learning_rate=0.1, n_estimators=300;, score=0.922 total time=   1.6s
# [CV 5/5] END learning_rate=0.1, n_estimators=300;, score=0.917 total time=   1.4s
# [CV 1/5] END learning_rate=0.05, n_estimators=100;, score=0.817 total time=   0.4s
# [CV 2/5] END learning_rate=0.05, n_estimators=100;, score=0.817 total time=   0.4s
# [CV 3/5] END learning_rate=0.05, n_estimators=100;, score=0.789 total time=   0.4s
# [CV 4/5] END learning_rate=0.05, n_estimators=100;, score=0.834 total time=   0.4s
# [CV 5/5] END learning_rate=0.05, n_estimators=100;, score=0.819 total time=   0.4s
# [CV 1/5] END learning_rate=0.05, n_estimators=200;, score=0.887 total time=   0.9s
# [CV 2/5] END learning_rate=0.05, n_estimators=200;, score=0.882 total time=   0.9s
# [CV 3/5] END learning_rate=0.05, n_estimators=200;, score=0.864 total time=   0.9s
# [CV 4/5] END learning_rate=0.05, n_estimators=200;, score=0.900 total time=   0.9s
# [CV 5/5] END learning_rate=0.05, n_estimators=200;, score=0.887 total time=   0.9s
# [CV 1/5] END learning_rate=0.05, n_estimators=300;, score=0.906 total time=   1.4s
# [CV 2/5] END learning_rate=0.05, n_estimators=300;, score=0.901 total time=   1.7s
# [CV 3/5] END learning_rate=0.05, n_estimators=300;, score=0.888 total time=   1.3s
# [CV 4/5] END learning_rate=0.05, n_estimators=300;, score=0.917 total time=   1.3s
# [CV 5/5] END learning_rate=0.05, n_estimators=300;, score=0.908 total time=   1.3s
# [CV 1/5] END learning_rate=0.2, n_estimators=100;, score=0.915 total time=   0.5s
# [CV 2/5] END learning_rate=0.2, n_estimators=100;, score=0.895 total time=   0.4s
# [CV 3/5] END learning_rate=0.2, n_estimators=100;, score=0.881 total time=   0.4s
# [CV 4/5] END learning_rate=0.2, n_estimators=100;, score=0.907 total time=   0.5s
# [CV 5/5] END learning_rate=0.2, n_estimators=100;, score=0.903 total time=   0.4s
# [CV 1/5] END learning_rate=0.2, n_estimators=200;, score=0.920 total time=   0.9s
# [CV 2/5] END learning_rate=0.2, n_estimators=200;, score=0.898 total time=   0.9s
# [CV 3/5] END learning_rate=0.2, n_estimators=200;, score=0.888 total time=   0.9s
# [CV 4/5] END learning_rate=0.2, n_estimators=200;, score=0.913 total time=   1.0s
# [CV 5/5] END learning_rate=0.2, n_estimators=200;, score=0.907 total time=   1.2s
# [CV 1/5] END learning_rate=0.2, n_estimators=300;, score=0.920 total time=   1.3s
# [CV 2/5] END learning_rate=0.2, n_estimators=300;, score=0.899 total time=   1.3s
# [CV 3/5] END learning_rate=0.2, n_estimators=300;, score=0.889 total time=   1.3s
# [CV 4/5] END learning_rate=0.2, n_estimators=300;, score=0.912 total time=   1.3s
# [CV 5/5] END learning_rate=0.2, n_estimators=300;, score=0.908 total time=   1.3s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.05, 0.2],
#                          'n_estimators': [100, 200, 300]},
#              verbose=3)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 300}

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# %%
print("Tuned model performance:")
print(f"R2 score: {r2_score(y_test, y_pred)}")
print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
# Out:
# Tuned model performance:
# R2 score: 0.9354889230445564
# Mean Absolute Error: 29.259660602381462
# Mean Squared Error: 1429.6471839775409
